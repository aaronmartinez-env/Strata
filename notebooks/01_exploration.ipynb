# %%
from src.data_loader import load_air_quality
from src.aqi_model import compute_scientific_aqi
from src.events import detect_calima_events
from src.air_mass import classify_air_mass
from src.attribution import compute_attribution
from src.complexity import compute_aci

# Load data

aq = load_air_quality()

# Compute AQI

aq = compute_scientific_aqi(aq)

# Detect calima

aq = detect_calima_events(aq)

# Air mass classification

aq = classify_air_mass(aq)

# Attribution

aq = compute_attribution(aq)

# Complexity

aq = compute_aci(aq)

# Inspect

aq.head()
